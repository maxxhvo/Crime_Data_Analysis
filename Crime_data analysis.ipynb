# %%
import os
import csv
import pandas as pd
import matplotlib as mpl

# %%
os.getcwd()
# Out:
# 'C:\\Users\\maxha\\Desktop\\Data Science Project'

# %%
crime_data  = pd.read_csv('Crime_Data_from_2020_to_Present.csv')

# %%
crime_data
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0       190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 3       200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# ...           ...                     ...                     ...       ...
# 892929  241604405  01/14/2024 12:00:00 AM  01/13/2024 12:00:00 AM       720
# 892930  241604246  01/08/2024 12:00:00 AM  01/08/2024 12:00:00 AM       800
# 892931  242004546  01/16/2024 12:00:00 AM  01/16/2024 12:00:00 AM      1510
# 892932  240705409  02/02/2024 12:00:00 AM  01/31/2024 12:00:00 AM        30
# 892933  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
#
# ...

# %%
crime_data.shape

#892934 rows and 28 columns
